# %% [raw]
# CS 210 Term Project Alper Arda OLGUN 00031199

# %%
Does watching series rather than movies on Netflix increase our screentime?

# %% [raw]
# As we all know nowadays lots of people are using subscription based entertainment services to spend time. Main reason people go for subscription based services can be narrowed two specific points: no advertisements and
# no need to wait for the episode. As this business model eliminates wait time for reaching an episode or a movie
# from my point of view it also increases the time spent in front of the screen due to no need to wait to watch a movie or a series as they are readily available in large quantities and you can watch anything back to back without getting interrupted. There is also another question here and my main aim is to answer this question, does watching series rather than movies on Netflix increase our screentime. From my perspective it does increase our screentime to watch series instead of movies due to watching episodes back to back due to our curiosity as in series a plot can take quite a high number of episodes to conclude which will keep us watching.
# For this analysis I will be using Netflix as it is one of the most popular subscription based entertainment services and I also have enough viewing history there to analyze.
# Aim of this project is to analyze my Netflix viewing history in order to understand does watching series or films
# have an impact on the time spent watching netflix and make predictions for future consumption habits.

# %% [raw]
# As netflix does not give a clear divided dataset to use ,and they give unrelated
# content in unrelated classifications, for their regular subscribers firstly
# I had to use some of excels built in data text to column features in order to be able to use the dataset.
# This process should not happen in a dataset destined to be analyzed unlike this list as netflix provides this
# list just to let people see what they have watched during their subscription period.

# %%
Load the Dataset:

# %%
import pandas as pd

# Assuming your CSV file is named 'netflix_history.csv'
df = pd.read_csv('NetflixViewingHistory(3).csv')

# %% [raw]
# First print to see what we have

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('NetflixViewingHistory(3).csv', skipinitialspace=True)

# Transpose the DataFrame and print
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df.T)
# Out:
#                                                                 0    \
# name;season;episode;date   Best. Christmas. Ever!;film;0;12.30.2023
#
#                                                        1    \
# name;season;episode;date   Groundhog Day;film;0;10.01.2023
#
#                                                         2    \
# name;season;episode;date   Johnny English;film;0;10.01.2023
#
#                                                                3    \
# name;season;episode;date   Johnny English Reborn;film;0;10.01.2023
#
#                                                         4    \
# name;season;episode;date   The Highwaymen;film;0;10.01.2023
#
#                                                        5    \
# name;season;episode;date   Miss Americana;film;0;9.30.2023
#
#                                                                          6    \
# name;season;episode;date   Taylor Swift reputation Stadium Tour;film;0;9....
#
# ...

# %% [raw]
# Now lets seperate film and series to two different lists.

# %%
import pandas as pd

# Load the dataset and split into separate columns
df = pd.read_csv('NetflixViewingHistory(3).csv', sep=';', skipinitialspace=True)

# Rename columns for clarity
df.columns = ['name', 'season', 'episode', 'date']

# Identify films and series
films_df = df[df['season'].str.lower() == 'film']
series_df = df[df['season'].str.lower() != 'film']

# Print films and series without separating rows
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print("Films:")
    print(films_df.to_string(index=False, header=False))

    print("\nSeries:")
    print(series_df.to_string(index=False, header=False))
# Out:
# Films:
#                            Best. Christmas. Ever! film 0 12.30.2023
#                                     Groundhog Day film 0 10.01.2023
#                                    Johnny English film 0 10.01.2023
#                             Johnny English Reborn film 0 10.01.2023
#                                    The Highwaymen film 0 10.01.2023
#                                    Miss Americana film 0  9.30.2023
#              Taylor Swift reputation Stadium Tour film 0  9.30.2023
#                                          Non-Stop film 0  9.30.2023
#                      Johnny English Strikes Again film 0  9.16.2023
#                                            Nobody film 0  8.30.2023
#                                      Extraction 2 film 0  6.23.2023
#                                  İllegal Hayatlar film 0  6.17.2023
#                                          Devotion film 0  2.20.2023
#                                             Seven film 0  2.20.2023
# ...

# %% [raw]
# Now lets look at the movies and series i watched.

# %%
import pandas as pd

# Load the dataset and split into separate columns
df = pd.read_csv('NetflixViewingHistory(3).csv', sep=';', skipinitialspace=True)

# Rename columns for clarity
df.columns = ['name', 'season', 'episode', 'date']

# Identify films and series
films_df = df[df['season'].str.lower() == 'film']
series_df = df[df['season'].str.lower() != 'film']

# List of movies
movies_list = films_df['name'].tolist()

# Summarize series with total number of episodes
series_summary = series_df.groupby('name')['episode'].count().reset_index()

# List of series and total episodes
series_list = series_summary.apply(lambda row: f"{row['name']} ({row['episode']} episodes)", axis=1).tolist()

# Print movies and series
print("Movies:")
print('\n'.join(movies_list))

print("\nSeries:")
print('\n'.join(series_list))
# Out:
# Movies:
# Best. Christmas. Ever!
# Groundhog Day
# Johnny English
# Johnny English Reborn
# The Highwaymen
# Miss Americana
# Taylor Swift reputation Stadium Tour
# Non-Stop
# Johnny English Strikes Again
# Nobody
# Extraction 2
# İllegal Hayatlar
# Devotion
# Seven
# Zodiac
# Heat
# The Pale Blue Eye
# The Godfather Coda  The Death of Michael Corleone
# Glass Onion  A Knives Out Mystery
# The Adam Project
# The Gray Man
# Meet the Spartans
# The Dig
# The Blue Lagoon
# Public Enemies
# Shutter Island
# The Aviator
# The Dictator
# 6 Underground
# Schumacher
# Jack Reacher  Never Go Back
# Enola Holmes
# Operation Mincemeat
# The King's Speech
# Mamma Mia! Here We Go Again
# An Officer and a Gentleman
# No Escape
# Casino
# The Fighter
# Deepwater Horizon
# Argo
# Jack Reacher
# All the Money in the World
# Nefes
# The Departed
# The Big Short
# Patriots Day
# Ted
# The Foreigner
# Spenser Confidential
# Shooter
# Lone Survivor
# Polar
# Black Hawk Down
# Hacksaw Ridge
# My Fuhrer
# ...

# %% [raw]
# Now lets look at the daily number of consumption for series and films seperately.

# %%
import pandas as pd

# Load the dataset and split into separate columns
df = pd.read_csv('NetflixViewingHistory(3).csv', sep=';', skipinitialspace=True)

# Rename columns for clarity
df.columns = ['name', 'season', 'episode', 'date']

# Identify films and series
films_df = df[df['season'].str.lower() == 'film']
series_df = df[df['season'].str.lower() != 'film']

# Calculate the number of episodes and films per day based on the given watch dates
series_per_day = series_df.groupby('date')['episode'].count()
films_per_day = films_df.groupby('date')['name'].count()

# Print the results
print("Episodes per Day:")
print(series_per_day)

print("\nFilms per Day:")
print(films_per_day)
# Out:
# Episodes per Day:
# date
# 1.19.2023     1
# 1.20.2023     7
# 1.21.2023     6
# 1.22.2023    10
# 1.23.2023    10
# 1.25.2023    13
# 2.12.2023     1
# 5.19.2020     3
# 5.20.2020     1
# 5.21.2020     1
# 5.22.2020     3
# 5.23.2020     3
# 5.24.2020     2
# 5.30.2020     6
# 5.31.2020     4
# 6.06.2020     1
# 6.24.2022     9
# 6.28.2022     3
# 6.29.2022    48
# 7.01.2022    36
# 7.02.2022    27
# 7.03.2022    15
# 7.04.2022     5
# 7.06.2022     5
# 7.07.2022    21
# 7.08.2022    16
# 7.09.2022    11
# 7.10.2022     7
# 7.11.2022    12
# 7.12.2022    24
# 7.13.2022    12
# 7.14.2022    17
# 7.15.2022    14
# 7.16.2022     9
# 8.04.2021     1
# 9.27.2023     2
# 9.29.2023    12
# 9.30.2023     7
# Name: episode, dtype: int64
#
# Films per Day:
# date
# 1.19.2023     1
# 1.21.2023     1
# 10.01.2023    4
# 12.30.2023    1
# 2.12.2023     1
# 2.13.2023     1
# 2.19.2023     1
# 2.20.2023     2
# 4.07.2020     1
# 5.02.2020     1
# 5.03.2020     1
# 5.09.2020     2
# ...

# %% [raw]
# Now lets find avarage daily consumption per type of content i consume.

# %%
import pandas as pd

# Load the dataset and split into separate columns
df = pd.read_csv('NetflixViewingHistory(3).csv', sep=';', skipinitialspace=True)

# Rename columns for clarity
df.columns = ['name', 'season', 'episode', 'date']

# Identify films and series
films_df = df[df['season'].str.lower() == 'film']
series_df = df[df['season'].str.lower() != 'film']

# Calculate the number of episodes and films per day based on the given watch dates
series_per_day = series_df.groupby('date')['episode'].count()
films_per_day = films_df.groupby('date')['name'].count()

# Calculate the average per day
average_series_per_day = series_per_day.mean()
average_films_per_day = films_per_day.mean()

# Print the results
print(f"Average Episodes per Day: {average_series_per_day}")
print(f"Average Films per Day: {average_films_per_day}")

# Compare the averages
if average_series_per_day > average_films_per_day:
    print("You watch more series than films on average daily.")
elif average_series_per_day < average_films_per_day:
    print("You watch more films than series on average daily.")
else:
    print("You watch an equal number of series and films on average daily.")
# Out:
# Average Episodes per Day: 10.131578947368421
# Average Films per Day: 1.4883720930232558
# You watch more series than films on average daily.

# %% [raw]
# Now lets visualise the data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset and split into separate columns
df = pd.read_csv('NetflixViewingHistory(3).csv', sep=';', skipinitialspace=True)

# Rename columns for clarity
df.columns = ['name', 'season', 'episode', 'date']

# Identify films and series
films_df = df[df['season'].str.lower() == 'film']
series_df = df[df['season'].str.lower() != 'film']

# Calculate the number of episodes and films per day based on the given watch dates
series_per_day = series_df.groupby('date')['episode'].count()
films_per_day = films_df.groupby('date')['name'].count()

# Calculate the average per day
average_series_per_day = series_per_day.mean()
average_films_per_day = films_per_day.mean()

# Visualize the data
plt.bar(['Episodes', 'Films'], [average_series_per_day, average_films_per_day], color=['blue', 'orange'])
plt.title('Average Episodes and Films Per Day')
plt.xlabel('Category')
plt.ylabel('Average Per Day')
plt.show()

# %% [raw]
# Eventhought it seems episode are more than film we should acknowlege that series episodes are
# shorter than movies so we should look into the avarage time of episode of a series and movie. According to
# digitalcenter.org average length of a movie in 2021 is 131 minutes and according to medium.com writer Jonas
# average episode of a series is 42 minutes. So lets calculate how many minutes it takes daily to consume
# different type of media on average.

# %%
import pandas as pd

# Load the dataset and split into separate columns
df = pd.read_csv('NetflixViewingHistory(3).csv', sep=';', skipinitialspace=True)

# Rename columns for clarity
df.columns = ['name', 'season', 'episode', 'date']

# Identify films and series
films_df = df[df['season'].str.lower() == 'film']
series_df = df[df['season'].str.lower() != 'film']

# Average lengths (in minutes)
average_movie_length = 131  # source: digitalcenter.org
average_series_episode_length = 42  # source: medium.com

# Calculate the number of episodes and films per day based on the given watch dates
series_per_day = series_df.groupby('date')['episode'].count()
films_per_day = films_df.groupby('date')['name'].count()

# Calculate the average time spent per day (in minutes)
average_series_per_day = series_per_day.mean() * average_series_episode_length
average_films_per_day = films_per_day.mean() * average_movie_length

# Convert average time to hours
average_hours_series, remainder_series = divmod(average_series_per_day, 60)
average_hours_films, remainder_films = divmod(average_films_per_day, 60)

# Print the results
print("Average Time Spent Per Day on a day you watch Series:")
print(f"{int(average_hours_series)} hours and {int(remainder_series)} minutes")

print("\nAverage Time Spent Per Day on a day you watch Films:")
print(f"{int(average_hours_films)} hours and {int(remainder_films)} minutes")

# Calculate the difference
difference_hours, difference_remainder = divmod(abs(average_series_per_day - average_films_per_day), 60)
print("\nDifference in Time Spent Per Day between a series watching day and film watching day:")
print(f"{int(difference_hours)} hours and {int(difference_remainder)} minutes")
# Out:
# Average Time Spent Per Day on a day you watch Series:
# 7 hours and 5 minutes
#
# Average Time Spent Per Day on a day you watch Films:
# 3 hours and 14 minutes
#
# Difference in Time Spent Per Day between a series watching day and film watching day:
# 3 hours and 50 minutes

# %% [raw]
# Now lets visualise the results.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset and split into separate columns
df = pd.read_csv('NetflixViewingHistory(3).csv', sep=';', skipinitialspace=True)

# Rename columns for clarity
df.columns = ['name', 'season', 'episode', 'date']

# Identify films and series
films_df = df[df['season'].str.lower() == 'film']
series_df = df[df['season'].str.lower() != 'film']

# Average lengths (in minutes)
average_movie_length = 131  # source: digitalcenter.org
average_series_episode_length = 42  # source: medium.com

# Calculate the number of episodes and films per day based on the given watch dates
series_per_day = series_df.groupby('date')['episode'].count()
films_per_day = films_df.groupby('date')['name'].count()

# Calculate the average time spent per day (in minutes)
average_series_per_day = series_per_day.mean() * average_series_episode_length
average_films_per_day = films_per_day.mean() * average_movie_length

# Convert average time to hours
average_hours_series, remainder_series = divmod(average_series_per_day, 60)
average_hours_films, remainder_films = divmod(average_films_per_day, 60)

# Print the results
print("Average Time Spent Per Day on a day you watch Series:")
print(f"{int(average_hours_series)} hours and {int(remainder_series)} minutes")

print("\nAverage Time Spent Per Day on a day you watch Films:")
print(f"{int(average_hours_films)} hours and {int(remainder_films)} minutes")

# Calculate the difference
difference_hours, difference_remainder = divmod(abs(average_series_per_day - average_films_per_day), 60)
print("\nDifference in Time Spent Per Day between Series and Films:")
print(f"{int(difference_hours)} hours and {int(difference_remainder)} minutes")

# Visualize the data
plt.bar(['Series', 'Films', 'Difference'], [average_series_per_day, average_films_per_day, abs(average_series_per_day - average_films_per_day)], color=['blue', 'orange', 'green'])
plt.title('Average Time Spent Per Day')
plt.xlabel('Category')
plt.ylabel('Average Time (minutes)')
plt.show()
# Out:
# Average Time Spent Per Day on a day you watch Series:
# 7 hours and 5 minutes
#
# Average Time Spent Per Day on a day you watch Films:
# 3 hours and 14 minutes
#
# Difference in Time Spent Per Day between Series and Films:
# 3 hours and 50 minutes

# %% [raw]
# From this calculations and from my previous viewing history it is safe to say that
# watching series rather than films result in significantly more time spent watching something,
# approximately two times more time spent while wathcing series.

# %%
Machine Learning Part:

# %% [raw]
# Using time series analysis to understand patterns, trends and seasonality in time ordered data by studyiny my netflix viewing history to see how my film or series preference change over time in monthly basis. Month which does not have any viewing history are not included in plotted diagram.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Load the dataset and split into separate columns
df = pd.read_csv('NetflixViewingHistory(3).csv', sep=';', skipinitialspace=True)

# Rename columns for clarity
df.columns = ['name', 'season', 'episode', 'date']

# Convert 'date' column to datetime format with different date formats
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Set 'date' column as the index for time series analysis
df.set_index('date', inplace=True)

# Identify films and series
films_df = df[df['season'].str.lower() == 'film']
series_df = df[df['season'].str.lower() != 'film']

# Resample the time series data by month and count the number of series/films watched each month
monthly_series_count = series_df.resample('M').size()
monthly_films_count = films_df.resample('M').size()

# Exclude months without any data
monthly_series_count = monthly_series_count[monthly_series_count > 0]
monthly_films_count = monthly_films_count[monthly_films_count > 0]

# Plot the time series data
plt.figure(figsize=(14, 6))

plt.plot(monthly_series_count.index, monthly_series_count, marker='o', linestyle='-', color='blue', label='Series')
plt.plot(monthly_films_count.index, monthly_films_count, marker='o', linestyle='-', color='orange', label='Films')

plt.title('Monthly Netflix Watching Habits')
plt.xlabel('Month (mm.yyyy)')
plt.ylabel('Number of Episodes/Films Watched')
plt.xticks(monthly_series_count.index, [month.strftime('%m.%Y') for month in monthly_series_count.index], rotation=45, ha='right')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()

# %% [raw]
# Plotting by time spent on the series or movies monthly.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Load the dataset and split into separate columns
df = pd.read_csv('NetflixViewingHistory(3).csv', sep=';', skipinitialspace=True)

# Rename columns for clarity
df.columns = ['name', 'season', 'episode', 'date']

# Convert 'date' column to datetime format with different date formats
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Set 'date' column as the index for time series analysis
df.set_index('date', inplace=True)

# Identify films and series
films_df = df[df['season'].str.lower() == 'film']
series_df = df[df['season'].str.lower() != 'film']

# Average lengths (in minutes)
average_movie_length = 131  # Update with your actual value
average_series_episode_length = 42  # Update with your actual value

# Resample the time series data by month and calculate the time spent on series and films each month
monthly_series_time = (series_df.resample('M')['episode'].count() * average_series_episode_length).fillna(0)
monthly_films_time = (films_df.resample('M')['name'].count() * average_movie_length).fillna(0)

# Exclude months without any data
monthly_series_time = monthly_series_time[monthly_series_time > 0]
monthly_films_time = monthly_films_time[monthly_films_time > 0]

# Plot the time series data
plt.figure(figsize=(14, 6))

plt.plot(monthly_series_time.index, monthly_series_time, marker='o', linestyle='-', color='blue', label='Series')
plt.plot(monthly_films_time.index, monthly_films_time, marker='o', linestyle='-', color='orange', label='Films')

plt.title('Monthly Netflix Watching Habits (Time Spent)')
plt.xlabel('Month (mm.yyyy)')
plt.ylabel('Time Spent (minutes)')
plt.xticks(monthly_series_time.index, [month.strftime('%m.%Y') for month in monthly_series_time.index], rotation=45, ha='right')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()

# %% [raw]
# Using linear regression to predict the number of series and films i will probably watch in the next month:

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import numpy as np

# Load the dataset and split into separate columns
df = pd.read_csv('NetflixViewingHistory(3).csv', sep=';', skipinitialspace=True)

# Rename columns for clarity
df.columns = ['name', 'season', 'episode', 'date']

# Convert 'date' column to datetime format with different date formats
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Set 'date' column as the index for time series analysis
df.set_index('date', inplace=True)

# Identify films and series
films_df = df[df['season'].str.lower() == 'film']
series_df = df[df['season'].str.lower() != 'film']

# Resample the time series data by month and count the number of series/films watched each month
monthly_series_count = series_df.resample('M').size().fillna(0)
monthly_films_count = films_df.resample('M').size().fillna(0)

# Ensure that the lengths are the same
min_length = min(len(monthly_series_count), len(monthly_films_count))
monthly_series_count = monthly_series_count[:min_length]
monthly_films_count = monthly_films_count[:min_length]

# Prepare the data for machine learning
monthly_data = pd.DataFrame({'Month': monthly_series_count.index, 'Series': monthly_series_count.values, 'Films': monthly_films_count.values})
monthly_data['Month'] = pd.to_numeric(monthly_data['Month'].astype(str).str.replace('-', ''))  # Convert datetime to numeric for regression

# Split the data into training and testing sets
train_data, test_data = train_test_split(monthly_data, test_size=0.2, shuffle=False)

# Train a linear regression model
model = LinearRegression()
model.fit(train_data[['Month']], train_data['Series'])

# Predict the number of series for the next month
next_month = np.array([[train_data['Month'].max() + 1]])
predicted_series = int(model.predict(next_month)[0])

# Train a linear regression model for films
model_films = LinearRegression()
model_films.fit(train_data[['Month']], train_data['Films'])

# Predict the number of films for the next month
predicted_films = int(model_films.predict(next_month)[0])

# Output the results
print("Predicted Number of Series for the Next Month:", predicted_series)
print("Predicted Number of Films for the Next Month:", predicted_films)
# Out:
# Predicted Number of Series for the Next Month: 20
# Predicted Number of Films for the Next Month: 0
# C:\Users\Alper Arda OLGUN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\Alper Arda OLGUN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [raw]
# Lets do the previous assumption with the possible expected to be spent.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import numpy as np

# Load the dataset and split into separate columns
df = pd.read_csv('NetflixViewingHistory(3).csv', sep=';', skipinitialspace=True)

# Rename columns for clarity
df.columns = ['name', 'season', 'episode', 'date']

# Convert 'date' column to datetime format with different date formats
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Set 'date' column as the index for time series analysis
df.set_index('date', inplace=True)

# Identify films and series
films_df = df[df['season'].str.lower() == 'film']
series_df = df[df['season'].str.lower() != 'film']

# Resample the time series data by month and count the number of series/films watched each month
monthly_series_count = series_df.resample('M').size().fillna(0)
monthly_films_count = films_df.resample('M').size().fillna(0)

# Ensure that the lengths are the same
min_length = min(len(monthly_series_count), len(monthly_films_count))
monthly_series_count = monthly_series_count[:min_length]
monthly_films_count = monthly_films_count[:min_length]

# Prepare the data for machine learning
monthly_data = pd.DataFrame({'Month': monthly_series_count.index, 'Series': monthly_series_count.values, 'Films': monthly_films_count.values})
monthly_data['Month'] = pd.to_numeric(monthly_data['Month'].astype(str).str.replace('-', ''))  # Convert datetime to numeric for regression

# Split the data into training and testing sets
train_data, test_data = train_test_split(monthly_data, test_size=0.2, shuffle=False)

# Train a linear regression model
model = LinearRegression()
model.fit(train_data[['Month']], train_data['Series'])

# Predict the number of series for the next month
next_month = np.array([[train_data['Month'].max() + 1]])
predicted_series = int(model.predict(next_month)[0])

# Train a linear regression model for films
model_films = LinearRegression()
model_films.fit(train_data[['Month']], train_data['Films'])

# Predict the number of films for the next month
predicted_films = int(model_films.predict(next_month)[0])

# Average time spent per episode or film (in minutes)
average_series_episode_length = 42  # Update with your actual value
average_movie_length = 131  # Update with your actual value

# Calculate expected time to be spent
expected_time_series = predicted_series * average_series_episode_length
expected_time_films = predicted_films * average_movie_length

# Convert expected time to hours and minutes
hours_series, remainder_series = divmod(expected_time_series, 60)
hours_films, remainder_films = divmod(expected_time_films, 60)

# Output the results
print("Predicted Number of Series for the Next Month:", predicted_series)
print("Predicted Number of Films for the Next Month:", predicted_films)
print("\nExpected Time to be Spent on Series:")
print(f"{int(hours_series)} hours and {int(remainder_series)} minutes")
print("\nExpected Time to be Spent on Films:")
print(f"{int(hours_films)} hours and {int(remainder_films)} minutes")
# Out:
# Predicted Number of Series for the Next Month: 20
# Predicted Number of Films for the Next Month: 0
#
# Expected Time to be Spent on Series:
# 14 hours and 0 minutes
#
# Expected Time to be Spent on Films:
# 0 hours and 0 minutes
# C:\Users\Alper Arda OLGUN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\Alper Arda OLGUN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [raw]
# Lets also look at the daily expectation on time and number of content.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import numpy as np

# Load the dataset and split into separate columns
df = pd.read_csv('NetflixViewingHistory(3).csv', sep=';', skipinitialspace=True)

# Rename columns for clarity
df.columns = ['name', 'season', 'episode', 'date']

# Convert 'date' column to datetime format with different date formats
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Set 'date' column as the index for time series analysis
df.set_index('date', inplace=True)

# Identify films and series
films_df = df[df['season'].str.lower() == 'film']
series_df = df[df['season'].str.lower() != 'film']

# Resample the time series data by day and count the number of series/films watched each day
daily_series_count = series_df.resample('D').size().fillna(0)
daily_films_count = films_df.resample('D').size().fillna(0)

# Ensure that the lengths are the same
min_length = min(len(daily_series_count), len(daily_films_count))
daily_series_count = daily_series_count[:min_length]
daily_films_count = daily_films_count[:min_length]

# Prepare the data for machine learning
daily_data = pd.DataFrame({'Date': daily_series_count.index, 'Series': daily_series_count.values, 'Films': daily_films_count.values})
daily_data['Date'] = pd.to_numeric(daily_data['Date'].astype(str).str.replace('-', ''))  # Convert datetime to numeric for regression

# Split the data into training and testing sets
train_data, test_data = train_test_split(daily_data, test_size=0.2, shuffle=False)

# Train a linear regression model
model = LinearRegression()
model.fit(train_data[['Date']], train_data['Series'])

# Predict the number of series for the next day
next_day = np.array([[train_data['Date'].max() + 1]])
predicted_series = int(model.predict(next_day)[0])

# Train a linear regression model for films
model_films = LinearRegression()
model_films.fit(train_data[['Date']], train_data['Films'])

# Predict the number of films for the next day
predicted_films = int(model_films.predict(next_day)[0])

# Average time spent per episode or film (in minutes)
average_series_episode_length = 42  # Update with your actual value
average_movie_length = 131  # Update with your actual value

# Calculate expected time to be spent
expected_time_series = predicted_series * average_series_episode_length
expected_time_films = predicted_films * average_movie_length

# Convert expected time to hours and minutes
hours_series, remainder_series = divmod(expected_time_series, 60)
hours_films, remainder_films = divmod(expected_time_films, 60)

# Output the results
print("Predicted Number of Series for the Next Day:", predicted_series)
print("Predicted Number of Films for the Next Day:", predicted_films)
print("\nExpected Time to be Spent on Series:")
print(f"{int(hours_series)} hours and {int(remainder_series)} minutes")
print("\nExpected Time to be Spent on Films:")
print(f"{int(hours_films)} hours and {int(remainder_films)} minutes")
# Out:
# Predicted Number of Series for the Next Day: 1
# Predicted Number of Films for the Next Day: 0
#
# Expected Time to be Spent on Series:
# 0 hours and 42 minutes
#
# Expected Time to be Spent on Films:
# 0 hours and 0 minutes
# C:\Users\Alper Arda OLGUN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\Alper Arda OLGUN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [raw]
# During Fall 2023 CS210 we were encouraged to use ChatGPT 3.5 so here is my chat log
# from ChatGPT 3.5: https://chat.openai.com/share/abe01d52-5530-4e5e-8891-e91dae78d38c
